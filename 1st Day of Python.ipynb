# %%
print("Hello World") # This is commnet
# Out:
# Hello World

# %%
Name = "Akshay Manjramkar" 
Age = 30
Old = False
a = None
Price = 15.00

print(type(Name))
print(type(Age))
print(type(Price))
print(type(Old))
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
a = 1000
b = 500
diff = a-b
print(diff)
# Out:
# 500

# %%
#Arithmetic Operations

a = 5
b = 2

print(a%b) # Reminder
print (a**b) # Power
print(a==b)
print(a!=b)
# Out:
# 1
# 25
# False
# True

# %%
name = input("enter your name: ")
age = int(input("enter age: "))
marks = float(input("enter marks: "))

print("welcome", name)
print("age =", age)
print("marks =", marks)
# Out:
# enter your name:  Akshay
# enter age:  30
# enter marks:  80
# welcome Akshay
# age = 30
# marks = 80.0

# %%
print(type(val), val)
# Out:
# <class 'float'> 30.0

# %%
# 1 Que: Write a Program to input 2 numbers & print their sum.

first = int(input("enter first: "))
second = int(input("enter second: "))

print("sum=", first+second)
# Out:
# enter first:  965
# enter second:  125
# sum= 1090

# %%
# 2 Que: WAP to input of a square & print its area.

side = float(input("enter square side: "))

print("area=", side**2)
# Out:
# enter square side:  4
# area= 16.0

# %%
# 3 Que: WAP to input 2 floating point numbers & print their average.

a = float(input("enter first: "))
b = float(input("enter second"))

print("avg= ",(a+b)/2)
# Out:
# enter first:  16.5
# enter second 3.5
# avg=  10.0

# %%
# 4 Que: WAP to input 2 int numbers, a and b. Print True if a is greater than or equal to b. if not print False.

a = int(input("enter first: "))
b = int(input("enter second: "))

print(a >= b)
# Out:
# enter first:  45
# enter second:  55
# False
